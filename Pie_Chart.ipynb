# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
val = [1600,600,100,410,250]
label_val=["Home rent","Food", "Phone/Internet Bill","Car","Other Utilities"]

# %%
plt.axis("equal")
plt.pie(val,labels=label_val, radius=1.5, autopct="%0.2f%%", explode=[0.2,0,0.2,0,0])
plt.show()
