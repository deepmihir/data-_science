# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blood_sugar= [113,85,90,150,149,88,93,115,80,135,77,82,129]
w_blood_sugar= [100,80,95,160,140,80,96,120,70,130,77,82,129]

# plt.hist(blood_sugar, bins=3, rwidth=0.95, color='g')

# %%
plt.title('Sugar level')
plt.xlabel('Sugar')
plt.ylabel('Person')
plt.hist([blood_sugar,w_blood_sugar], bins=3, rwidth=0.95, color=['green','orange'], label=['Men','Women'])
plt.legend()
